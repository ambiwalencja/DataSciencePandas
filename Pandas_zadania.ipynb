# %%
# 1. Załaduj zbiór danych korzystajac z biblioteki Pandas. 
import pandas as pd
df = pd.read_csv('dataset_pandas_pd.csv',
                 delimiter=',',
                 names=['imie', 'nazwisko', 'rok_ur', 'miesiac_ur', 'dzien_ur', 'miejsce_ur', 'miasto', 'departament',
                        'rok_pracy', 'miesiac_pracy', 'dzien_pracy', 'doswiadczenie'])

# %%
# 2. Osób o jakim nazwisku jest najwięcej ?
print(df.groupby('nazwisko').nazwisko.count().sort_values()[[-1]])
# print(df[['nazwisko']].groupby('nazwisko').nazwisko.count().sort_values()[[-1]])
# Out:
# nazwisko
# Abacki    7
# Name: nazwisko, dtype: int64

# %%
# 3. Po kolumnie z nazwiskiem dodaj kolumnę reprezentującą płeć danej osoby. Można wykorzystać fakt, że imiona
# kobiet kończą się literka 'a'.
sex_values = ['K' if name[-1]=='a' else 'M' for name in list(df['imie'])] # uwaga na składnię tu!
df.insert(2, 'plec', sex_values) # insert(gdzie, nazwa, wartości) https://www.geeksforgeeks.org/python-pandas-dataframe-insert/
df.head()
# list(df['imie'])
# Out:
#       imie nazwisko plec  rok_ur  miesiac_ur  dzien_ur miejsce_ur  miasto  \
# 0     Adam   Abacki    M    1970           3         4     Gdansk  Gdansk
# 1  Barbara  Babacka    K    1971           4         5     Gdynia  Gdansk
# 2   Celina  Cabacka    K    1969           6         7      Sopot  Gdansk
# 3  Dariusz  Dabacki    M    1972           8         9     Lublin  Gdansk
# 4  Ewelina   Ebacka    K    1968          10        11   Warszawa  Gdansk
#
#             departament  rok_pracy  miesiac_pracy  dzien_pracy  doswiadczenie
# 0          Data Science     2015.0              4            5             20
# 1          Data Science        NaN              5           15             10
# 2  Software Development     2013.0              6           25             35
# 3                    HR     2020.0              4            5              4
# 4            Accounting     2000.0              7           15             30

# %%
# 4. Posortuj zbiór danych alfabetycznie po nazwiskach, a w ramach jednego nazwiska po roku urodzenia.
df.sort_values(by=['nazwisko', 'rok_ur'])
# Out:
#           imie nazwisko plec  rok_ur  miesiac_ur  dzien_ur   miejsce_ur  \
# 22   Anastazja   Abacka    K    1990           6        21       Gdansk
# 38      Alicja   Abacka    K    1992           2         5       Gdansk
# 16       Roman   Abacki    M    1962           2        23       Lublin
# 0         Adam   Abacki    M    1970           3         4       Gdansk
# 9       Janusz   Abacki    M    1975           9        16       Gdynia
# 23      Antoni   Abacki    M    1982           7        20     Warszawa
# 35      Antoni   Abacki    M    1984           5         8         Ryki
# 28  Franciszek   Abacki    M    1993          12        15       Lublin
# 32      Wiktor   Abacki    M    1995           8        11       Gdansk
# 10    Karolina  Babacka    K    1965           8        17      Legnica
# 1      Barbara  Babacka    K    1971           4         5       Gdynia
# 17  Stanislawa  Babacka    K    1979           1        24   Inowroclaw
# 39     Barbara  Babacka    K    1982           1         4        Sopot
# 33       Magda  Babacka    K    1985           7        10       Lublin
# 24       Beata  Babacka    K    1991           8        19       Krakow
# 29    Boleslaw  Babacki    M    1985          11        14     Katowice
# 36   Bronislaw  Babacki    M    1993           4         7       Gdansk
# 2       Celina  Cabacka    K    1969           6         7        Sopot
# 18      Tomasz  Cabacki    M    1961           2        25    Bydgoszcz
# 11        Leon  Cabacki    M    1976           7        18      Wroclaw
# 25      Cezary  Cabacki    M    1983           9        18       Gdynia
# 37      Horacy  Cabacki    M    1983           3         6   Tarnobrzeg
# 30     Dariusz  Cabacki    M    1994          10        13     Katowice
# 34      Maciej  Cabacki    M    1994           6         9     Warszawa
# 19     Urszula  Dabacka    K    1980           3        24    Bydgoszcz
# 12      Michal  Dabacki    M    1964           6        19  Swinoujscie
# 3      Dariusz  Dabacki    M    1972           8         9       Lublin
# 31     Mariusz  Dabacki    M    1986           9        12       Gdansk
# 26      Daniel  Dabacki    M    1992          10        17       Gdansk
# 4      Ewelina   Ebacka    K    1968          10        11     Warszawa
# 13     Natalia   Ebacka    K    1977           5        20     Zakopane
# 27         Ewa   Ebacka    K    1984          11        16     Zakopane
# 20   Wladyslaw   Ebacki    M    1960           4        23       Poznan
# 21       Zofia  Fabacka    K    1981           5        22       Gdansk
# 14       Oskar  Fabacki    M    1963           4        21       Gdansk
# 5    Ferdynand  Fabacki    M    1973          11        12    Walbrzych
# 15    Patrycja  Gabacka    K    1978           3        22      Rzeszow
# 6     Grzegorz  Gabacki    M    1967          12        13       Gdansk
# 7       Halina  Habacka    K    1974          11        14     Warszawa
# 8        Iwona   Ibacka    K    1966          10        15       Poznan
#
#       miasto           departament  rok_pracy  miesiac_pracy  dzien_pracy  \
# 22    Krakow                    HR     2017.0              9           25
# 38  Warszawa            Accounting        NaN              3           15
# 16    Krakow          Data Science        NaN              5           12
# 0     Gdansk          Data Science     2015.0              4            5
# 9     Gdansk                 Sales     1995.0             11            5
# 23    Krakow                    HR     2018.0             10           20
# 35  Warszawa                    HR     2015.0              5           10
# 28    Krakow          Data Science     1997.0              4           25
# 32  Warszawa            Accounting     2018.0              4           15
# 10    Gdansk          Data Science     2005.0              4           15
# 1     Gdansk          Data Science        NaN              5           15
# 17    Krakow  Software Development     2012.0              4            5
# 39  Warszawa          Data Science        NaN              2            5
# 33  Warszawa  Software Development     2017.0              4           12
# 24    Krakow  Software Development     2019.0              4           24
# 29    Krakow          Data Science     1998.0              4           25
# 36  Warszawa                    HR     2014.0              4           22
# 2     Gdansk  Software Development     2013.0              6           25
# 18    Krakow          Data Science     2013.0              6           13
# 11    Krakow          Data Science     2006.0              4           25
# 25    Krakow          Data Science        NaN              4           21
# 37  Warszawa          Data Science     2013.0              4           25
# 30    Krakow            Accounting     1999.0              9            5
# 34  Warszawa          Data Science     2016.0              6           11
# 19    Krakow          Data Science     2014.0              4           14
# 12    Gdansk                    HR     2007.0             12            5
# 3     Gdansk                    HR     2020.0              4            5
# 31  Warszawa            Accounting     2019.0              8            5
# 26    Krakow  Software Development     1995.0             12            5
# 4     Gdansk            Accounting     2000.0              7           15
# 13    Krakow                    HR     2008.0              4           10
# 27    Krakow  Software Development     1996.0             11           15
# 20    Krakow          Data Science     2015.0              7           16
# 21    Krakow                    HR        NaN              8           25
# 14    Krakow          Data Science     2009.0              4           25
# 5     Gdansk                    HR     2001.0              8           25
# 15    Krakow  Software Development     2010.0              4            5
# 6     Gdansk  Software Development     2002.0              4            5
# 7     Gdansk            Accounting     2003.0              9           15
# 8     Gdansk                 Sales     2004.0             10           25
#
#     doswiadczenie
# 22             13
# 38             13
# 16              8
# 0              20
# 9              20
# 23             12
# 35             16
# 28              8
# 32              4
# 10             30
# 1              10
# 17              7
# 39             10
# 33             18
# 24             11
# 29              7
# 36             15
# 2              35
# 18              6
# 11             24
# 25             12
# 37             14
# 30              6
# 34             17
# 19              5
# 12             21
# 3               4
# 31              5
# 26             10
# 4              30
# 13             20
# 27              9
# 20             15
# 21             14
# 14             10
# 5              20
# 15              9
# 6              18
# 7              17
# 8              16

# %%
# 5. Do zbioru danych należy dodać kolumnę, która będzie mówiła o poziomie doświadczenia danej osoby, w sposób
# słowny, przyjmując:

# Junior (do 3 lat doświadczenia)
# Mid (4 do 8 lat)
# Senior (9 do 12 lat)
# Ekspert (od 13 lat)

# tutaj juz myśle, że warunek zbyt złożony, żeby zrobić to wyrażeniem skróconym
experience_levels = []
for experience in list(df['doswiadczenie']):
    if experience <= 3:
        experience_levels.append('Junior')
    elif experience in range(4,9):
        experience_levels.append('Mid')
    elif experience in range(9,13):
        experience_levels.append('Senior')
    else:
        experience_levels.append('Ekspert')
df['poziom_dosw'] = experience_levels
df.head()
# Out:
#       imie nazwisko plec  rok_ur  miesiac_ur  dzien_ur miejsce_ur  miasto  \
# 0     Adam   Abacki    M    1970           3         4     Gdansk  Gdansk
# 1  Barbara  Babacka    K    1971           4         5     Gdynia  Gdansk
# 2   Celina  Cabacka    K    1969           6         7      Sopot  Gdansk
# 3  Dariusz  Dabacki    M    1972           8         9     Lublin  Gdansk
# 4  Ewelina   Ebacka    K    1968          10        11   Warszawa  Gdansk
#
#             departament  rok_pracy  miesiac_pracy  dzien_pracy  doswiadczenie  \
# 0          Data Science     2015.0              4            5             20
# 1          Data Science        NaN              5           15             10
# 2  Software Development     2013.0              6           25             35
# 3                    HR     2020.0              4            5              4
# 4            Accounting     2000.0              7           15             30
#
#   poziom_dosw
# 0     Ekspert
# 1      Senior
# 2     Ekspert
# 3         Mid
# 4     Ekspert
